# %%
import pyam

df = pyam.IamDataFrame(data="AR6_Scenarios_Database_R5_regions_v1.1.csv")
# Out:
# pyam.core - INFO: Reading file AR6_Scenarios_Database_R5_regions_v1.1.csv

# %%
df
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : AIM/CGE 2.0, AIM/CGE 2.1, AIM/CGE 2.2, ... WITCH-GLOBIOM 4.4 (100)
#  * scenario : 1, 1.5C, 1.5C OPEC sell-out, 1.5CNow_Gradual, ... peak2025_DemandLow_FossilLow_TechHigh (935)
# Timeseries data coordinates:
#    region   : R5ASIA, R5LAM, R5MAF, R5OECD90+EU, R5REF, R5ROWO (6)
#    variable : Agricultural Demand, Agricultural Demand|Crops, ... Yield|Sugarcrops (1318)
#    unit     : %, -, EJ/yr, GW, GW/yr, GWh, GWh/yr, ... °C (68)
#    year     : 1990, 1995, 2000, 2001, 2002, 2003, 2004, 2005, ... 2100 (39)

# %%
df.model
# Out:
# ['AIM/CGE 2.0',
#  'AIM/CGE 2.1',
#  'AIM/CGE 2.2',
#  'AIM/Hub-Global 2.0',
#  'BET EMF33',
#  'C-GEM 3.0',
#  'C-ROADS-5.005',
#  'C3IAM 1.0',
#  'C3IAM 2.0',
#  'CGE-MOD 1.0',
#  'COFFEE 1.1',
#  'CONTO-RUS 1.0',
#  'COPPE-COFFEE 1.0',
#  'DART 1.0',
#  'DNE21+ V.14C',
#  'DNE21+ V.14E1',
#  'DNE21+ V.14E2',
#  'DNE21+ V.ADVANCE',
#  'E3ME 6.1',
#  'EC-MSMR 1.0',
#  'EDF-GEPA 1.0',
#  'EDGE-Buildings 1.0',
#  'EDGE-Buildings 2.0',
#  'EDGE-Buildings 3.0',
#  'ENV-Linkages 3.0',
#  'ENVISAGE 10.01',
#  'EPPA 6',
#  'FARM 3.2',
#  'GAINS-dw4',
#  'GCAM 4.0',
#  'GCAM 4.2',
#  'GCAM 5.2',
#  'GCAM 5.3',
#  'GCAM-PR 5.3',
#  'GCAM5.2_NET',
#  'GEM-E3 V1',
#  'GEM-E3_V2021',
#  'GEMINI-E3 7.0',
#  'GENeSYS-MOD 1.0',
#  'GMM-17',
#  'GRAPE-15 1.0',
#  'Global TIMES 2.0',
#  'Global Transportation Roadmap 2019.05',
#  'HEB 2.0',
#  'ICES-EMF 1.0',
#  'ICES-XPS 1.0',
#  'IIASAPOP 2.0',
#  'IMACLIM 1.1',
#  'IMACLIM-NLU 1.0',
#  'IMAGE 3.0',
#  'IMAGE 3.0.1',
#  'IMAGE 3.0.2',
# ...

# %%
df.scenario
# Out:
# ['1',
#  '1.5C',
#  '1.5C OPEC sell-out',
#  '1.5CNow_Gradual',
#  '1.5CNow_OptTax',
#  '2.5C',
#  '20% abatement (FF&I)',
#  '20% abatement (GHG)',
#  '2C',
#  '2C OPEC sell-out',
#  '2C-hybrid',
#  '2C-normal',
#  '2C-with BECCS',
#  '2C-with CCS',
#  '2CNow_Gradual',
#  '2CNow_OptTax',
#  '2DC',
#  '450 concentration',
#  '450ppmCancunP',
#  '450ppmRCP',
#  '450ppmeINDC',
#  '50% abatement (FF&I)',
#  '50% abatement (GHG)',
#  '550 concentration',
#  '650 concentration',
#  'ADVANCE_2020_1.5C-2100',
#  'ADVANCE_2020_1.5C-2100_WP6',
#  'ADVANCE_2020_Med2C',
#  'ADVANCE_2020_Med2C_WP6',
#  'ADVANCE_2020_WB2C',
#  'ADVANCE_2020_WB2C_WP6',
#  'ADVANCE_2030_1.5C-2100',
#  'ADVANCE_2030_Med2C',
#  'ADVANCE_2030_Med2C_WP6',
#  'ADVANCE_2030_Price1.5C',
#  'ADVANCE_2030_Price1.5C_WP6',
#  'ADVANCE_2030_WB2C',
#  'ADVANCE_2030_WB2C_WP6',
#  'ADVANCE_INDC',
#  'ADVANCE_INDC_WP6',
#  'ADVANCE_NoPolicy',
#  'ADVANCE_NoPolicy_WP6',
#  'ADVANCE_Reference',
#  'ADVANCE_Reference_WP6',
# ...

# %%
df.region
# Out:
# ['R5ASIA', 'R5LAM', 'R5MAF', 'R5OECD90+EU', 'R5REF', 'R5ROWO']

# %%
df.unit_mapping
# Out:
# {'Agricultural Demand': 'million t DM/yr',
#  'Agricultural Demand|Crops': 'million t DM/yr',
#  'Agricultural Demand|Crops|Energy': 'million t DM/yr',
#  'Agricultural Demand|Crops|Energy|1st generation': 'million t DM/yr',
#  'Agricultural Demand|Crops|Energy|2nd generation': 'million t DM/yr',
#  'Agricultural Demand|Crops|Feed': 'million t DM/yr',
#  'Agricultural Demand|Crops|Food': 'million t DM/yr',
#  'Agricultural Demand|Crops|Other': 'million t DM/yr',
#  'Agricultural Demand|Livestock': 'million t DM/yr',
#  'Agricultural Demand|Livestock|Food': 'million t DM/yr',
#  'Agricultural Demand|Livestock|Other': 'million t DM/yr',
#  'Agricultural Production': 'million t DM/yr',
#  'Agricultural Production|Energy': 'million t DM/yr',
#  'Agricultural Production|Energy|Crops': 'million t DM/yr',
#  'Agricultural Production|Energy|Residues': 'million t DM/yr',
#  'Agricultural Production|Non-Energy': 'million t DM/yr',
# ...

# %%
df.filter(model="REMIND 2.1").scenario
# Out:
# ['CEMICS_GDPgrowth_1p5',
#  'CEMICS_GDPgrowth_2C',
#  'CEMICS_HotellingConst_1p5',
#  'CEMICS_HotellingConst_2C',
#  'CEMICS_Linear_1p5',
#  'CEMICS_Linear_2C',
#  'CEMICS_NPI',
#  'CEMICS_opt_1p5',
#  'CEMICS_opt_2C',
#  'LeastTotalCost_Base_brkLR15_SSP1_P50',
#  'LeastTotalCost_Base_brkLR15_SSP2_P50',
#  'LeastTotalCost_Base_brkLR15_SSP5_P50',
#  'LeastTotalCost_Base_brkSR15_SSP1_P50',
#  'LeastTotalCost_Base_brkSR15_SSP2_P50',
#  'LeastTotalCost_Base_brkSR15_SSP5_P50',
#  'LeastTotalCost_CBA_brkLR15_SSP2_P50',
#  'LeastTotalCost_CBA_brkSR15_SSP2_P50',
#  'LeastTotalCost_CEA_brkLR15_SSP2_P50',
#  'LeastTotalCost_CEA_brkSR15_SSP2_P50',
#  'LeastTotalCost_LTC_brkLR15_SSP1_P50',
#  'LeastTotalCost_LTC_brkLR15_SSP2_P50',
#  'LeastTotalCost_LTC_brkLR15_SSP5_P50',
#  'LeastTotalCost_LTC_brkSR15_SSP1_P50',
#  'LeastTotalCost_LTC_brkSR15_SSP2_P50',
#  'LeastTotalCost_LTC_brkSR15_SSP5_P50',
#  'LeastTotalCost_NDC_brkLR15_SSP2_P50',
#  'LeastTotalCost_NDC_brkSR15_SSP2_P50',
# ...

# %%
df.filter(region="World", keep=False).region
# Out:
# ['R5ASIA', 'R5LAM', 'R5MAF', 'R5OECD90+EU', 'R5REF', 'R5ROWO']

# %%
display_df = df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Electricity", region="R5OECD90+EU")
display_df.timeseries()
# Out:
#                                                                                                                 2005
# model      scenario                             region      variable                           unit
# REMIND 2.1 CEMICS_GDPgrowth_1p5                 R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ   0.000000  \
#            CEMICS_GDPgrowth_2C                  R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ   0.000000
#            CEMICS_HotellingConst_1p5            R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ   0.000000
#            CEMICS_HotellingConst_2C             R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ   0.000000
#            CEMICS_Linear_1p5                    R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ   0.000000
#            CEMICS_Linear_2C                     R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ   0.000000
# ...

# %%
display_df.filter(year=[2010, 2030, 2050]).timeseries()
# Out:
#                                                                                                                 2010
# model      scenario                             region      variable                           unit
# REMIND 2.1 CEMICS_GDPgrowth_1p5                 R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.434267  \
#            CEMICS_GDPgrowth_2C                  R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.434267
#            CEMICS_HotellingConst_1p5            R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.434267
#            CEMICS_HotellingConst_2C             R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.434267
#            CEMICS_Linear_1p5                    R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.434267
#            CEMICS_Linear_2C                     R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.434267
# ...

# %%
display_df = df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Electricity", scenario="R2p1_SSP2-Base", region="R5OECD90+EU")
display_df.timeseries()
# Out:
#                                                                                          2005
# model      scenario       region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  5.449872  \
#
#                                                                                           2010
# model      scenario       region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.872966  \
#
#                                                                                           2015
# model      scenario       region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  13.437282  \
#
#                                                                                           2020
# ...

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
display_df = df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Electricity", 
                       scenario=additional_scenarios, region="R5OECD90+EU")
display_df.timeseries()
# Out:
#                                                                                                2005
# model      scenario             region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  5.449872  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  5.449872
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  5.449872
#
#                                                                                                 2010
# model      scenario             region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  10.872966  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  11.599448
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  11.599448
# ...

# %%
display_df.filter(year=[2030, 2040, 2050]).timeseries()
# Out:
#                                                                                                 2030
# model      scenario             region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  20.079728  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  30.243054
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  36.622356
#
#                                                                                                 2040
# model      scenario             region      variable                           unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  17.509537  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Electricity US$2010/GJ  18.232419
# ...

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Electricity", 
                       scenario=additional_scenarios, region="R5OECD90+EU").plot(color="scenario")
# Out:
# <Axes: title={'center': 'model: REMIND 2.1 - region: R5OECD90+EU - variable: Price|Secondary Energy|Electricity'}, xlabel='Year', ylabel='US$2010/GJ'>

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
display_df = df.filter(model="REMIND 2.1*", variable="Price|Primary Energy|Biomass", 
                       scenario=additional_scenarios, region="R5OECD90+EU")
display_df.timeseries()
# Out:
#                                                                                        2005
# model      scenario             region      variable                     unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.1602  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.1602
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.1602
#
#                                                                                       2010
# model      scenario             region      variable                     unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.674  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.674
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.674
#
# ...

# %%
display_df.filter(year=[2030, 2040, 2050]).timeseries()
# Out:
#                                                                                        2030
# model      scenario             region      variable                     unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  1.1590  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  6.5457
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  7.6433
#
#                                                                                         2040
# model      scenario             region      variable                     unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ   2.2064  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ   7.5672
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Primary Energy|Biomass US$2010/GJ  14.2434
#
# ...

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
df.filter(model="REMIND 2.1*", variable="Price|Primary Energy|Biomass", 
                       scenario=additional_scenarios, region="R5OECD90+EU").plot(color="scenario")
# Out:
# <Axes: title={'center': 'model: REMIND 2.1 - region: R5OECD90+EU - variable: Price|Primary Energy|Biomass'}, xlabel='Year', ylabel='US$2010/GJ'>

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
display_df = df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Liquids|Biomass", 
                       scenario=additional_scenarios, region="R5OECD90+EU")
display_df.timeseries()
# Out:
#                                                                                                    2005
# model      scenario             region      variable                               unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ -0.000482  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ -0.000482
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ -0.000482
#
#                                                                                                     2010
# model      scenario             region      variable                               unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  10.494523  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  10.494523
# ...

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
display_df = df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Gases|Natural Gas", 
                       scenario=additional_scenarios, region="R5OECD90+EU")
display_df.filter(year=[2030, 2040, 2050]).timeseries()
# Out:
#                                                                                                       2030
# model      scenario             region      variable                                 unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Gases|Natural Gas US$2010/GJ   8.608288  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Gases|Natural Gas US$2010/GJ  17.027489
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Secondary Energy|Gases|Natural Gas US$2010/GJ  27.458570
#
#                                                                                                       2040
# model      scenario             region      variable                                 unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Gases|Natural Gas US$2010/GJ   9.119002  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Gases|Natural Gas US$2010/GJ  21.282485
# ...

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Gases|Natural Gas", 
                       scenario=additional_scenarios, region="R5OECD90+EU").plot(color="scenario")
# Out:
# <Axes: title={'center': 'model: REMIND 2.1 - region: R5OECD90+EU - variable: Price|Secondary Energy|Gases|Natural Gas'}, xlabel='Year', ylabel='US$2010/GJ'>

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
display_df = df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Liquids|Biomass", 
                       scenario=additional_scenarios, region="R5OECD90+EU")
display_df.filter(year=[2030, 2040, 2050]).timeseries()
# Out:
#                                                                                                     2030
# model      scenario             region      variable                               unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  21.491741  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  30.214236
#            R2p1_SSP2-PkBudg900  R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  41.075280
#
#                                                                                                     2040
# model      scenario             region      variable                               unit
# REMIND 2.1 R2p1_SSP2-Base       R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  20.754602  \
#            R2p1_SSP2-PkBudg1100 R5OECD90+EU Price|Secondary Energy|Liquids|Biomass US$2010/GJ  31.916958
# ...

# %%
# Define additional scenarios
additional_scenarios = ["R2p1_SSP2-Base", "R2p1_SSP2-PkBudg1100", "R2p1_SSP2-PkBudg900"]  # Add your scenarios here

# Filter using multiple scenarios
df.filter(model="REMIND 2.1*", variable="Price|Secondary Energy|Liquids|Biomass", 
                       scenario=additional_scenarios, region="R5OECD90+EU").plot(color="scenario")
# Out:
# <Axes: title={'center': 'model: REMIND 2.1 - region: R5OECD90+EU - variable: Price|Secondary Energy|Liquids|Biomass'}, xlabel='Year', ylabel='US$2010/GJ'>
